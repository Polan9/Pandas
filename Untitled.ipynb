# %%
import pandas as pd
import numpy as np
import sys
import matplotlib.pyplot as plt

# %% [markdown]
# ## Zadanie 1

# %%
pd.set_option("display.max_columns",300)

data = pd.read_csv("pokemon_data.csv")

df = pd.DataFrame(data)

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %% [markdown]
# ## Zadanie 2

# %%
bez_na = df.dropna()

# %%
bez_na
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 6      6              Charizard     Fire  Flying  78      84       78
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
Only_na = df[df["Type 2"].isnull()]

# %%
Only_na
# Out:
#        #        Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 4      4  Charmander    Fire    NaN   39      52       43       60       50
# 5      5  Charmeleon    Fire    NaN   58      64       58       80       65
# 9      7    Squirtle   Water    NaN   44      48       65       50       64
# 10     8   Wartortle   Water    NaN   59      63       80       65       80
# 11     9   Blastoise   Water    NaN   79      83      100       85      105
# ..   ...         ...     ...    ...  ...     ...      ...      ...      ...
# 775  705     Sliggoo  Dragon    NaN   68      75       53       83      113
# 776  706      Goodra  Dragon    NaN   90     100       70      110      150
# 788  712    Bergmite     Ice    NaN   55      69       85       32       35
# 789  713     Avalugg     Ice    NaN   95     117      184       44       46
# 792  716     Xerneas   Fairy    NaN  126     131       95      131       98
#
#      Speed  Generation  Legendary
# ...

# %% [markdown]
# ## Zadanie 3

# %%
df.sort_values(by=["HP","Defense","Sp. Def"],ascending=True)
# Out:
#        #       Name    Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292   Shedinja       Bug  Ghost    1      90       45       30       30
# 55    50    Diglett    Ground    NaN   10      55       25       35       45
# 186  172      Pichu  Electric    NaN   20      40       15       35       35
# 381  349     Feebas     Water    NaN   20      15       20       10       55
# 487  439   Mime Jr.   Psychic  Fairy   20      25       45       70       90
# ..   ...        ...       ...    ...  ...     ...      ...      ...      ...
# 655  594  Alomomola     Water    NaN  165      75       80       40       45
# 351  321    Wailord     Water    NaN  170      90       45       90       45
# 217  202  Wobbuffet   Psychic    NaN  190      33       58       33       58
# 121  113    Chansey    Normal    NaN  250       5        5       35      105
# 261  242    Blissey    Normal    NaN  255      10       10       75      135
#
#      Speed  Generation  Legendary
# ...

# %%
df.sort_values(by=["Attack", "Sp. Atk", "Speed"], ascending=False)
# Out:
#        #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 232  214  HeracrossMega Heracross      Bug  Fighting   80     185      115
# 429  386       DeoxysAttack Forme  Psychic       NaN   50     180       20
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# ..   ...                      ...      ...       ...  ...     ...      ...
# 261  242                  Blissey   Normal       NaN  255      10       10
# 139  129                 Magikarp    Water       NaN   20      10       55
# 230  213                  Shuckle      Bug      Rock   20      10      230
# 121  113                  Chansey   Normal       NaN  250       5        5
# 488  440                  Happiny   Normal       NaN  100       5        5
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.insert(12,"Total Def",df["HP"] + df["Defense"] + df["Sp. Def"])

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total Def  Total Off
# ...

# %%
df.insert(13,"Total Off",df["Attack"] + df["Sp. Atk"] + df["Speed"])

# %%
df =df.drop('Rank Off', axis=1)

# %%
df.insert(14,"Rank Off",df["Total Off"].rank())

# %%
df.insert(15,"Rank Def",df["Total Def"].rank())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16048\1166736237.py in ?()
# ----> 1 df.insert(15,"Rank Def",df["Total Def"].rank())
#
# ~\PycharmProjects\pythonProject16\venv\lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    5154                 "'self.flags.allows_duplicate_labels' is False."
#    5155             )
#    5156         if not allow_duplicates and column in self.columns:
#    5157             # Should this be a different kind of error??
# -> 5158             raise ValueError(f"cannot insert {column}, already exists")
#    5159         if not is_integer(loc):
#    5160             raise TypeError("loc must be int")
#    5161         # convert non stdlib ints to satisfy typing checks
#
# ValueError: cannot insert Rank Def, already exists

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total Def  Total Off  \
# ...

# %%
df.sort_values("Rank Off",ascending=False).head(5)
# Out:
#        #                   Name   Type 1    Type 2   HP  Attack  Defense  \
# 429  386     DeoxysAttack Forme  Psychic       NaN   50     180       20
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN  106     150       70
# 426  384  RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 428  386     DeoxysNormal Forme  Psychic       NaN   50     150       50
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total Def  Total Off  \
# 429      180       20    150           3       True         90        510
# 164      194      120    140           1       True        296        484
# 426      180      100    115           3       True        305        475
# 163      154      100    130           1       True        306        474
# 428      150       50    150           3       True        150        450
#
#      Rank Off  Rank Def
# 429     800.0       7.0
# 164     799.0     710.5
# ...

# %%
df.sort_values("Rank Def",ascending=False).head(5)
# Out:
#        #                   Name   Type 1  Type 2   HP  Attack  Defense  \
# 230  213                Shuckle      Bug    Rock   20      10      230
# 261  242                Blissey   Normal     NaN  255      10       10
# 224  208    SteelixMega Steelix    Steel  Ground   75     125      230
# 269  249                  Lugia  Psychic  Flying  106      90      130
# 544  487  GiratinaAltered Forme    Ghost  Dragon  150     100      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total Def  Total Off  \
# 230       10      230      5           2      False        480         25
# 261       75      135     55           2      False        400        140
# 224       55       95     30           2      False        400        210
# 269       90      154    110           2       True        390        290
# 544      100      120     90           4       True        390        290
#
#      Rank Off  Rank Def
# 230       1.0     800.0
# 261     103.0     798.5
# ...

# %% [markdown]
# ## Zadanie 4

# %%
values = df[df["Name"].str.contains("os") & df["Name"].str.contains("Mega")]

# %%
len(values)
# Out:
# 5

# %%
values
# Out:
#        #                     Name    Type 1    Type 2  HP  Attack  Defense  \
# 141  130    GyaradosMega Gyarados     Water      Dark  95     155      109
# 196  181    AmpharosMega Ampharos  Electric    Dragon  90      95      105
# 232  214  HeracrossMega Heracross       Bug  Fighting  80     185      115
# 413  376  MetagrossMega Metagross     Steel   Psychic  80     145      150
# 420  381        LatiosMega Latios    Dragon   Psychic  80     130      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 141       70      130     81           1      False
# 196      165      110     45           2      False
# 232       40      105     75           2      False
# 413      105      110    110           3      False
# 420      160      120    110           3       True

# %%
wykres = values.plot.bar(x="#",y=["HP","Defense","Attack","Sp. Atk","Sp. Def", "Speed"],rot=0)
wykres.legend(loc=2)

# %% [markdown]
# ## Zadanie 5

# %%
n_df = df

# %%
n_df.insert(12,"Total", n_df["HP"] + n_df["Speed"] + n_df["Sp. Def"] + n_df["Attack"] + n_df["Defense"] + n_df["Sp. Atk"])

# %%
n_df.insert(13,"Pseudo Legendary",bool)

# %%
n_df.loc[df["Total"] > 500, "Pseudo Legendary"] = True
n_df.loc[df["Total"] < 500, "Pseudo Legendary"] = False

# %%
n_df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total Pseudo Legendary
# ...

# %%
summary = n_df.groupby(by="Generation")[["Legendary"]].sum()

# %%
summary = summary.reset_index()
summary.plot.bar(x="Generation")
# Out:
# <Axes: xlabel='Generation'>

# %% [markdown]
# ## Zadanie 6

# %%
n_df = df
n_df = n_df.drop(["Type 1","Type 2","Generation","Legendary","Name"],axis=1)

# %%
n_df
# Out:
#        #  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Total Pseudo Legendary
# 0      1  45      49       49       65       65     45    318            False
# 1      2  60      62       63       80       80     60    405            False
# 2      3  80      82       83      100      100     80    525             True
# 3      3  80     100      123      122      120     80    625             True
# 4      4  39      52       43       60       50     65    309            False
# ..   ...  ..     ...      ...      ...      ...    ...    ...              ...
# 795  719  50     100      150      100      150     50    600             True
# 796  719  50     160      110      160      110    110    700             True
# 797  720  80     110       60      150      130     70    600             True
# 798  720  80     160       60      170      130     80    680             True
# 799  721  80     110      120      130       90     70    600             True
#
# [800 rows x 9 columns]

# %%
n_df.to_csv("modified.csv")

# %%
data2 = pd.read_csv("modified.csv")

# %%
df2 = pd.DataFrame(data2)

# %%
polaczone = pd.merge(df,df2,on="#")
plot =  polaczone.plot(kind="scatter",x="Speed_x",y="Speed_y")

# %%
plot_HP =  polaczone.plot(kind="scatter",x="HP_x",y="HP_y")

# %%
plot_Attack =  polaczone.plot(kind="scatter",x="Attack_x",y="Attack_y")

# %%
plot_defense =  polaczone.plot(kind="scatter",x="Defense_x",y="Defense_y")

# %% [markdown]
# ## Zadanie 7

# %%
data2 = pd.read_csv("gen7.csv")

# %%
df2 = pd.DataFrame(data2)

# %%
df2 = df2.drop(["abilities","against_bug","against_dark","against_dragon","against_electric","against_fairy","against_fight","against_fire",'against_flying'
                ,"against_ghost","against_grass","against_ground","against_ice","against_normal","against_poison","against_psychic","against_rock","against_steel"
                ,"against_water","base_egg_steps","base_happiness","base_total","capture_rate","classfication","experience_growth","height_m","japanese_name","percentage_male"
                ,"pokedex_number","weight_kg"],axis=1)

# %%
df2 = df2.rename(columns={"name" : "Name","attack":"Attack","hp":"HP","defense":"Defense","sp_attack":"Sp. Attack","sp_defense":"Sp. Defense","speed":"Speed","type1":"Type 1"
                    ,"type2":"Type 2","generation":"Generation","is_legendary":"Legendary"})

# %%
df = pd.concat([df,df2],join="inner",ignore_index=True)

# %%
df
# Out:
#       Attack  Defense   HP        Name  Speed   Type 1  Type 2  Generation  \
# 0         55       55   68      Rowlet     42    grass  flying           7
# 1         75       75   78     Dartrix     52    grass  flying           7
# 2        107       75   78   Decidueye     70    grass   ghost           7
# 3         65       40   45      Litten     70     fire     NaN           7
# 4         85       50   65    Torracat     90     fire     NaN           7
# ...      ...      ...  ...         ...    ...      ...     ...         ...
# 1035     101      103   97  Celesteela     61    steel  flying           7
# 1036     181      131   59     Kartana    109    grass   steel           7
# 1037     101       53  223    Guzzlord     43     dark  dragon           7
# 1038     107      101   97    Necrozma     79  psychic     NaN           7
# 1039      95      115   80    Magearna     65    steel   fairy           7
#
#       Legendary
# 0             0
# 1             0
# ...

# %%
df.to_csv("pokemon_extended.csv")

# %%
df.tail()
# Out:
#       Attack  Defense   HP        Name  Speed   Type 1  Type 2  Generation  \
# 1035     101      103   97  Celesteela     61    steel  flying           7
# 1036     181      131   59     Kartana    109    grass   steel           7
# 1037     101       53  223    Guzzlord     43     dark  dragon           7
# 1038     107      101   97    Necrozma     79  psychic     NaN           7
# 1039      95      115   80    Magearna     65    steel   fairy           7
#
#       Legendary
# 1035          1
# 1036          1
# 1037          1
# 1038          1
# 1039          1

# %% [markdown]
# ## Zadanie 8

# %%
data2 = pd.read_csv("pokemon_extended.csv")

# %%
df2 = pd.DataFrame(data2)

# %%
summary = df2.groupby(by="Type 1").size()

# %%
summary
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# bug          27
# dark          3
# dragon        9
# electric      9
# fairy         3
# fighting      9
# fire         15
# ghost        12
# grass        36
# ground        6
# normal       36
# poison       12
# psychic      18
# rock         12
# steel         6
# water        27
# dtype: int64

# %%
summary.plot(kind="pie",x="Type 1", legend=True)
plt.legend(loc="lower left", bbox_to_anchor=(1.2, 0., 1., 1.))
plt.figure(figsize=(5.0,5.0))

# %% [markdown]
# ## Zadanie 9

# %%
df2.describe()
# Out:
#         Unnamed: 0       Attack      Defense           HP        Speed  \
# count  1040.000000  1040.000000  1040.000000  1040.000000  1040.000000
# mean    519.500000    80.301923    74.804808    69.562500    67.299038
# std     300.366443    32.449757    30.895418    26.157735    29.017137
# min       0.000000     5.000000     5.000000     1.000000     5.000000
# 25%     259.750000    55.000000    50.000000    50.000000    45.000000
# 50%     519.500000    75.000000    70.000000    67.000000    65.000000
# 75%     779.250000   100.000000    90.000000    80.000000    90.000000
# max    1039.000000   190.000000   230.000000   255.000000   180.000000
#
#         Generation    Legendary
# count  1040.000000  1040.000000
# mean      4.172115     0.111538
# std       2.126914     0.314949
# min       1.000000     0.000000
# 25%       2.000000     0.000000
# 50%       4.000000     0.000000
# 75%       6.000000     0.000000
# max       7.000000     1.000000

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
df2 = df2.rename(columns={"Unnamed: 0":"#"})
raport = df2.describe()
raport
# Out:
#             #  Attack  Defense      HP   Speed  Generation  Legendary
# count 1040.00 1040.00  1040.00 1040.00 1040.00     1040.00    1040.00
# mean   519.50   80.30    74.80   69.56   67.30        4.17       0.11
# std    300.37   32.45    30.90   26.16   29.02        2.13       0.31
# min      0.00    5.00     5.00    1.00    5.00        1.00       0.00
# 25%    259.75   55.00    50.00   50.00   45.00        2.00       0.00
# 50%    519.50   75.00    70.00   67.00   65.00        4.00       0.00
# 75%    779.25  100.00    90.00   80.00   90.00        6.00       0.00
# max   1039.00  190.00   230.00  255.00  180.00        7.00       1.00

# %%
boxplot = raport.boxplot(column="Attack",by="Attack",layout=(5,1),fontsize=5)

# %%
boxplot = raport.boxplot(column="Defense",by="Defense",layout=(5,1),fontsize=5)

# %%
boxplot = raport.boxplot(column="Speed",by="Speed",layout=(5,1),fontsize=5)

# %%
boxplot = raport.boxplot(column="HP",by="HP",layout=(5,1),fontsize=5)

# %%
boxplot = raport.boxplot(column="Legendary",by="Legendary",layout=(5,1),fontsize=5)

# %%
boxplot = raport.boxplot(column="Generation",by="Generation",layout=(5,1),fontsize=5)
